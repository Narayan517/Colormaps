# %%
import pandas as pd
import matplotlib.pyplot as plt

data={
    "Date":pd.to_datetime(["2022-01-01","2022-02-01","2022-03-01","2022-04-01","2022-05-01","2022-06-01","2022-07-01","2022-08-01","2022-09-01","2022-10-01"]),
    "value":[10,15,22,28,35,42,48,55,62,68]
}

df = pd.DataFrame(data)
df.set_index("Date",inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index, df["value"],marker='X')
plt.xlabel("Date")
plt.ylabel("value")
plt.title("Time series with Trend")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data={
    "Date":pd.to_datetime(["2022-01-01","2022-02-01","2022-03-01","2022-02-01","2022-03-01","2022-04-01","2022-05-01","2022-04-01","2022-03-01","2022-04-01"]),
    "value":[10,15,22,28,35,42,48,55,62,68]
}

df = pd.DataFrame(data)
df.set_index("value",inplace=True)
plt.figure(figsize=(10,6))
plt.plot(df.index, df["Date"],marker='X')
plt.xlabel("value")
plt.ylabel("Date")
plt.title("Time series with Seasonality")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

text_data = "the representation of data through use of common graphics, such as charts, plots, infographics and even animations"
WordCloud = WordCloud(width=800, height=400, background_color='Black').generate(text_data)

plt.figure(figsize=(10,5))
plt.bar(Counter(text_data).keys(), Counter(text_data).values())
plt.title("Histogram of word frequencies")
plt.xlabel("words")
plt.ylabel("frequency")
plt.xticks(rotation=90)
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a list of word
text=("Java is a widely-used programming language for coding web applications. It has been a popular choice among developers for over two decades, with millions of Java applications in use today ")

# Create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

def remove_stopwords(string):
  stop_words = set(stopwords.words('english'))
  words = string.split()
  filtered_words = (word for word in words if word.lower() not in stop_words)
  return ' '.join(filtered_words)

input_string = 'Java is a multi-platform, object-oriented, and network-centric language that can be used as a platform in itself.'
result = remove_stopwords(input_string)
print("Original string:", input_string)
print("Modified string:", result)
# Out:
# Original string: Java is a multi-platform, object-oriented, and network-centric language that can be used as a platform in itself.
# Modified string: Java multi-platform, object-oriented, network-centric language used platform itself.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
